# %%
a = int(input("Enter first integer: "))
b = int(input("Enter second integer: "))
print("Sum:",a + b)
print("Difference:", a - b)
print("Product:", a * b)
print("Division:", a / b)
# Out:
# Enter first integer: 88
# Enter second integer: 42
# Sum: 130
# Difference: 46
# Product: 3696
# Division: 2.0952380952380953
